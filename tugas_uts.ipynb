# %% [markdown]
# # Tutorial & Tugas UTS: EDA dan Pra-pemrosesan dengan Dask & GCS di Google Colab
#
# ## Tujuan Pembelajaran
#
# Dalam tutorial ini, Anda akan belajar cara melakukan analisis data eksplorasi (EDA) dan tugas UTS pra-pemrosesan data menggunakan Dask. Kita akan memproses kumpulan data besar yang disimpan di Google Cloud Storage (GCS) langsung dari Google Colab.

# %% [markdown]
# ## Bagian 1: Persiapan Environment

# %% [markdown]
# ### 1. Install Library
# Jalankan sel kode berikut untuk menginstal pustaka yang diperlukan (dask).

# %%
# !pip install gcsfs "dask[complete]"
# Out:
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.12/dist-packages (2025.3.0)
# Requirement already satisfied: dask[complete] in /usr/local/lib/python3.12/dist-packages (2025.9.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs) (3.13.2)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs) (4.4.2)
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.12/dist-packages (from gcsfs) (2025.3.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs) (1.2.3)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs) (2.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gcsfs) (2.32.4)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (8.3.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (0.12.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (18.1.0)
# Collecting lz4>=4.3.2 (from dask[complete])
#   Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs) (4.9.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (2.2.2)
# Requirement already satisfied: distributed==2025.9.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (2025.9.1)
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (3.7.3)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from dask[complete]) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (3.2.1)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.9.1->dask[complete]) (3.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs) (2.5.0)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gcsfs) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (4.15.0)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]) (2.11.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]) (11.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]) (2025.10.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.26.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->dask[complete]) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[complete]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[complete]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->dask[complete]) (2025.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[complete]) (1.17.0)
# Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: lz4
# Successfully installed lz4-4.4.5

# %% [markdown]
# ### 2. Mulai Klaster Dask
# Inisialisasi LocalCluster dan Client. Dask akan menggunakan core yang tersedia di mesin virtual Colab.

# %%
from dask.distributed import Client, LocalCluster
import dask.dataframe as dd

# Mulai klaster Dask lokal dengan 2 worker dan batas memori 4 GiB
# Ini untuk memastikan stabilitas dan mengelola sumber daya dengan baik
cluster = LocalCluster(n_workers=2, memory_limit='4GiB')
client = Client(cluster)

print(f"Dasbor Dask tersedia di: {client.dashboard_link}")
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:45019
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40333'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:36489'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:34571 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:34571
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:41156
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:38197 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38197
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:41164
# INFO:distributed.scheduler:Receive client connection: Client-9136c3eb-c14b-11f0-8433-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:41178
# Dasbor Dask tersedia di: http://127.0.0.1:8787/status

# %% [markdown]
# ### 3. Muat Data dari GCS
# Akses data penerbangan publik dari GCS. Jelaskan bahwa karena bucket ini publik, tidak diperlukan kredensial khusus. Dask secara otomatis menggunakan gcsfs untuk mengakses data.

# %%
# Tentukan path GCS ke data
gcs_path = "gcs://quansight-datasets/airline-ontime-performance/csv/*ber_2020.csv"


# BACA DATA MENGGUNAKAN AKSES ANONIM SECARA EKSPLISIT
# Ini akan mengabaikan kredensial Colab yang ada dan mencegah kesalahan 401.
df = dd.read_csv(gcs_path, assume_missing=True, storage_options={'token': 'anon'})
# df = dd.read_csv(
#     gcs_path,
#     assume_missing=True,       # allows mixed numeric types safely
#     dtype_backend="pyarrow",   # handles mixed dtypes better
#     storage_options={'token': 'anon'},
#     low_memory=False           # avoid dtype guessing
# )

# %% [markdown]
# ## Bagian 2: Analisis Data Eksplorasi (EDA) dengan Dask

# %% [markdown]
# ### 1. Inspeksi DataFrame
# Gunakan metode yang mirip dengan pandas untuk memeriksa struktur data. Pada saat yang diperlukan, gunakan .compute() untuk menjalankan penghitungan.

# %%
df = dd.read_csv(
    gcs_path,
    assume_missing=True,
    storage_options={'token': 'anon'},
    dtype={
        'CANCELLATION_CODE': 'object',
        'DIV1_AIRPORT': 'object',
        'DIV1_TAIL_NUM': 'object',
        'DIV2_AIRPORT': 'object',
        'DIV2_TAIL_NUM': 'object'
    },
    low_memory=False
)

# %%
# Tampilkan beberapa baris pertama dari Dask DataFrame
print(df.head())

# Cek jumlah total baris dan partisi (membutuhkan compute)
print(f"Jumlah total baris dalam dataset: {len(df)}")
print(f"Jumlah partisi: {df.npartitions}")
# Out:
#      YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                FL_DATE  \
# 0  2020.0      4.0   12.0           1.0          2.0  12/1/2020 12:00:00 AM
# 1  2020.0      4.0   12.0           1.0          2.0  12/1/2020 12:00:00 AM
# 2  2020.0      4.0   12.0           1.0          2.0  12/1/2020 12:00:00 AM
# 3  2020.0      4.0   12.0           1.0          2.0  12/1/2020 12:00:00 AM
# 4  2020.0      4.0   12.0           1.0          2.0  12/1/2020 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                9E                20363.0         9E   N131EV  ...
# 1                9E                20363.0         9E   N131EV  ...
# 2                9E                20363.0         9E   N131EV  ...
# 3                9E                20363.0         9E   N131EV  ...
# 4                9E                20363.0         9E   N131EV  ...
#
#    DIV4_WHEELS_OFF  DIV4_TAIL_NUM  DIV5_AIRPORT  DIV5_AIRPORT_ID  \
# 0              NaN            NaN           NaN              NaN
# 1              NaN            NaN           NaN              NaN
# 2              NaN            NaN           NaN              NaN
# 3              NaN            NaN           NaN              NaN
# 4              NaN            NaN           NaN              NaN
#
#   DIV5_AIRPORT_SEQ_ID DIV5_WHEELS_ON DIV5_TOTAL_GTIME  DIV5_LONGEST_GTIME  \
# 0                 NaN            NaN              NaN                 NaN
# 1                 NaN            NaN              NaN                 NaN
# 2                 NaN            NaN              NaN                 NaN
# 3                 NaN            NaN              NaN                 NaN
# 4                 NaN            NaN              NaN                 NaN
#
#   DIV5_WHEELS_OFF  DIV5_TAIL_NUM
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
#
# [5 rows x 109 columns]
# Jumlah total baris dalam dataset: 1411177
# Jumlah partisi: 7

# %% [markdown]
# ### 2. Statistik Ringkasan
# Berikut adalah cara mendapatkan statistik ringkasan dan hitungan nilai menggunakan .compute().

# %%
# Hitung statistik deskriptif untuk kolom numerik
print(df.describe().compute())

# Hitung jumlah nilai unik untuk kolom 'ORIGIN'
print(df['ORIGIN'].value_counts().compute().head())
# Out:
#             YEAR       QUARTER         MONTH  DAY_OF_MONTH   DAY_OF_WEEK  \
# count  1411177.0  1.411177e+06  1.411177e+06  1.411177e+06  1.411177e+06
# mean      2020.0  3.770867e+00  1.055538e+01  1.594778e+01  4.024031e+00
# std          0.0  4.202750e-01  1.109733e+00  8.790429e+00  2.013970e+00
# min       2020.0  3.000000e+00  9.000000e+00  1.000000e+00  1.000000e+00
# 25%       2020.0  3.000000e+00  9.000000e+00  9.000000e+00  3.000000e+00
# 50%       2020.0  4.000000e+00  1.000000e+01  1.600000e+01  4.000000e+00
# 75%       2020.0  4.000000e+00  1.100000e+01  2.400000e+01  6.000000e+00
# max       2020.0  4.000000e+00  1.200000e+01  3.100000e+01  7.000000e+00
#
#        OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# count           1.411177e+06       1.411177e+06       1.411177e+06
# mean            2.000502e+04       2.669464e+03       1.260339e+04
# std             3.808987e+02       1.845574e+03       1.548834e+03
# min             1.939300e+04       1.000000e+00       1.013500e+04
# 25%             1.979000e+04       1.213000e+03       1.129200e+04
# 50%             1.997700e+04       2.629000e+03       1.252300e+04
# 75%             2.037800e+04       4.629000e+03       1.405700e+04
# max             2.045200e+04       8.819000e+03       1.686900e+04
#
#        ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  ...  DIV4_WHEELS_OFF  \
# count           1.411177e+06           1.411177e+06  ...              0.0
# mean            1.260343e+06           3.170161e+04  ...              NaN
# std             1.548831e+05           1.348507e+03  ...              NaN
# min             1.013506e+06           3.007000e+04  ...              NaN
# 25%             1.129202e+06           3.055900e+04  ...              NaN
# 50%             1.252306e+06           3.145300e+04  ...              NaN
# 75%             1.405702e+06           3.257500e+04  ...              NaN
# max             1.686901e+06           3.599100e+04  ...              NaN
#
#        DIV4_TAIL_NUM  DIV5_AIRPORT  DIV5_AIRPORT_ID  DIV5_AIRPORT_SEQ_ID  \
# count            0.0           0.0              0.0                  0.0
# mean             NaN           NaN              NaN                  NaN
# std              NaN           NaN              NaN                  NaN
# min              NaN           NaN              NaN                  NaN
# 25%              NaN           NaN              NaN                  NaN
# 50%              NaN           NaN              NaN                  NaN
# 75%              NaN           NaN              NaN                  NaN
# max              NaN           NaN              NaN                  NaN
#
#        DIV5_WHEELS_ON  DIV5_TOTAL_GTIME  DIV5_LONGEST_GTIME  DIV5_WHEELS_OFF  \
# count             0.0               0.0                 0.0              0.0
# mean              NaN               NaN                 NaN              NaN
# std               NaN               NaN                 NaN              NaN
# min               NaN               NaN                 NaN              NaN
# 25%               NaN               NaN                 NaN              NaN
# 50%               NaN               NaN                 NaN              NaN
# 75%               NaN               NaN                 NaN              NaN
# max               NaN               NaN                 NaN              NaN
#
#        DIV5_TAIL_NUM
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#
# [8 rows x 90 columns]
# WARNING:distributed.shuffle._scheduler_plugin:Shuffle e47b32d1a39bdc6b71bdd5748e228b3a initialized by task ('shuffle-transfer-e47b32d1a39bdc6b71bdd5748e228b3a', 3) executed on worker tcp://127.0.0.1:34571
# WARNING:distributed.shuffle._scheduler_plugin:Shuffle e47b32d1a39bdc6b71bdd5748e228b3a deactivated due to stimulus 'task-finished-1763119490.7474942'
# ORIGIN
# ACV     305
# ACY     487
# AGS    1180
# ALS     104
# BKG      28
# Name: count, dtype: int64[pyarrow]

# %%
df['YEAR'].head()
# Out:
# 0    2020.0
# 1    2020.0
# 2    2020.0
# 3    2020.0
# 4    2020.0
# Name: YEAR, dtype: float64

# %% [markdown]
# ### 3. Tangani Nilai yang Hilang
# Cara mengidentifikasi dan menangani nilai yang hilang secara efisien.

# %%
# Hitung persentase nilai kosong per kolom
null_counts = df.isnull().sum().compute() / len(df)
print(null_counts[null_counts > 0])

# Ganti nilai kosong di kolom 'FL_NUM' dengan nilai rata-rata
df['DEP_DELAY'] = df['DEP_DELAY'].fillna(df['DEP_DELAY'].mean())
# Out:
# TAIL_NUM              0.001625
# DEP_TIME              0.006577
# DEP_DELAY             0.006579
# DEP_DELAY_NEW         0.006579
# DEP_DEL15             0.006579
#                         ...
# DIV5_WHEELS_ON        1.000000
# DIV5_TOTAL_GTIME      1.000000
# DIV5_LONGEST_GTIME    1.000000
# DIV5_WHEELS_OFF       1.000000
# DIV5_TAIL_NUM         1.000000
# Length: 71, dtype: float64

# %% [markdown]
# ## Bagian 3: Pra-pemrosesan Data dengan Dask

# %% [markdown]
# ### 1. Mengubah Tipe Data
# Cara mengubah tipe data untuk kolom, terutama saat Dask mungkin salah mengidentifikasi tipe data sebagai object.

# %%
# Ubah kolom 'YEAR' menjadi tipe integer
df['YEAR'] = df['YEAR'].astype(int)

# Ubah kolom bertipe object menjadi tipe category untuk efisiensi
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category')

# %% [markdown]
# ### 2. Rekayasa Fitur
# Membuat fitur baru dari kolom yang sudah ada.

# %%
# Buat fitur baru untuk durasi penerbangan
df['FLIGHT_DURATION'] = df['ARR_TIME'] - df['DEP_TIME']

# %% [markdown]
# ### 3. Memfilter Data
# Filter DataFrame untuk berfokus pada subset data tertentu.

# %%
# Filter penerbangan di tahun 2020 yang mengalami keterlambatan
delayed_flights_2020 = df[(df['YEAR'] == 2020) & (df['ARR_DELAY'] > 0)]

# Hitung ukuran DataFrame yang difilter
print(f"\nJumlah penerbangan yang tertunda di tahun 2020: {len(delayed_flights_2020)}")
# Out:
# Jumlah penerbangan yang tertunda di tahun 2020: 302740

# %% [markdown]
# ## Bagian 4: Visualisasi dengan Dask dan Matplotlib

# %% [markdown]
# ### 1. Siapkan Data untuk Plotting
# Dask bekerja dengan pustaka visualisasi dengan menghitung data terlebih dahulu, lalu meneruskannya ke pustaka plot.

# %%
df.OP_UNIQUE_CARRIER.head()
# Out:
# 0    9E
# 1    9E
# 2    9E
# 3    9E
# 4    9E
# Name: OP_UNIQUE_CARRIER, dtype: string

# %%
import matplotlib.pyplot as plt

# Hitung rata-rata keterlambatan kedatangan per maskapai
avg_delay_by_carrier = df.groupby('OP_UNIQUE_CARRIER')['ARR_DELAY'].mean().compute()

# Plot hasilnya menggunakan pandas dan matplotlib
plt.figure(figsize=(12, 6))
avg_delay_by_carrier.plot(kind='bar')
plt.title('Rata-rata Keterlambatan Kedatangan per Maskapai')
plt.xlabel('Maskapai')
plt.ylabel('Rata-rata Keterlambatan Kedatangan (menit)')
plt.show()

# %% [markdown]
# ## Bagian 5: Tugas UTS
# Sekarang giliran Anda! Jawab pertanyaan-pertanyaan di bawah ini menggunakan Dask di Google Colab.

# %% [markdown]
# ### Pertanyaan Konseptual
# Jelaskan dengan kata-kata Anda sendiri mengapa Dask diperlukan untuk dataset ini dan masalah apa yang dipecahkannya dibandingkan dengan menggunakan alat single-core seperti pandas.

# %% [markdown]
# #### Tuliskan Nama dan NIM di sini
#
# - NAMA: Wulan Nuri Rahmawati
# - NIM: 202210370311315

# %% [markdown]
# ### Pertanyaan Konseptual
#
# 1. Jelaskan dengan kata-kata Anda sendiri mengapa Dask diperlukan untuk dataset ini dan masalah apa yang dipecahkannya dibandingkan dengan menggunakan package single-core seperti pandas.
#
# ##### Jawaban:
# #Dask diperlukan untuk dataset ini karena pandas hanya bekerja dengan satu core CPU dan mengharuskan seluruh dataset dimuat sekaligus ke dalam memori. Ketika ukuran data sangat besar, penggunaan pandas menjadi lambat atau bahkan bisa menyebabkan error karena kehabisan memori. Dask memecahkan masalah ini dengan membagi dataset menjadi potongan-potongan kecil dan memprosesnya secara paralel menggunakan banyak core CPU. Dengan cara ini, Dask dapat menangani data yang lebih besar daripada kapasitas RAM serta mempercepat proses komputasi. Jadi, Dask memungkinkan pengolahan data besar secara efisien tanpa memerlukan perangkat keras yang sangat besar.

# %% [markdown]
# ### Pertanyaan Pemrograman

# %% [markdown]
# 2. Hitung rata-rata keterlambatan keberangkatan (DEP_DELAY) untuk setiap maskapai (OP_UNIQUE_CARRIER) dalam dataset. Tampilkan 5 maskapai teratas dengan rata-rata keterlambatan tertinggi.

# %%
# Jawab Pertanyaan-2 pada baris berikutnya (baris ini jangan dihapus)

# %% [markdown]
# 3. Menggunakan kolom FLIGHT_DURATION yang telah dibuat, filter DataFrame untuk menemukan semua penerbangan yang durasinya lebih dari 5 jam. Kemudian, hitung dan tampilkan jumlah total penerbangan tersebut.

# %%
# Jawab Pertanyaan-3 pada baris berikutnya (baris ini jangan dihapus)

# %% [markdown]
# 4. Buat plot yang menampilkan jumlah total penerbangan yang tertunda (ARR_DELAY > 0) per tahun. Pastikan untuk melabeli plot dengan jelas.

# %%
# Jawab Pertanyaan-4 pada baris berikutnya (baris ini jangan dihapus)

# %% [markdown]
# 5. Pertanyaan Bonus: Buat fitur baru bernama FLIGHT_SPEED (dalam mil per menit) dan gunakan untuk menemukan penerbangan dengan kecepatan tertinggi yang tercatat.

# %%
# Jawab Pertanyaan-5 pada baris berikutnya (baris ini jangan dihapus)

# %% [markdown]
# ### Bagian 6: Pembersihan
# Setelah selesai, tutup klaster Dask.

# %%
client.close()
cluster.close()
